# %%
def deluxe_deals(func):
    def inner():
        func()
        print('Hey here you go your buurger with cheese and beacon')
    return inner

@deluxe_deals #Here we are overwriting this old fucntion in this mehtod
def buy_burger():
    print('Order placed')
    
buy_burger()
# Out:
# Order placed
# Hey here you go your buurger with cheese and beacon

# %%
def deluxe_deals1(func):
    def inner():
        func()
        print("Hey man here is you burger with cheese and beacon")
    return inner

def buy_burger1():
    print('order placed')

burger=deluxe_deals1(buy_burger1) #Here we are not overwriting the old fucntion we just copying it with this addition features to a  new fucntion
burger()
# Out:
# order placed
# Hey man here is you burger with cheese and beacon
